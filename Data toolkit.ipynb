# %%
import numpy as np

# Generate an array of 100 evenly spaced numbers between 1 and 10
array_1d = np.linspace(1, 10, 100)

# Reshape the array into a 2D array (e.g., 10 rows and 10 columns)
array_2d = array_1d.reshape(10, 10)

# Print the results
print("1D Array:")
print(array_1d)
print("\n2D Array:")
print(array_2d)
# Out:
# 1D Array:
# [ 1.          1.09090909  1.18181818  1.27272727  1.36363636  1.45454545
#   1.54545455  1.63636364  1.72727273  1.81818182  1.90909091  2.
#   2.09090909  2.18181818  2.27272727  2.36363636  2.45454545  2.54545455
#   2.63636364  2.72727273  2.81818182  2.90909091  3.          3.09090909
#   3.18181818  3.27272727  3.36363636  3.45454545  3.54545455  3.63636364
#   3.72727273  3.81818182  3.90909091  4.          4.09090909  4.18181818
#   4.27272727  4.36363636  4.45454545  4.54545455  4.63636364  4.72727273
#   4.81818182  4.90909091  5.          5.09090909  5.18181818  5.27272727
#   5.36363636  5.45454545  5.54545455  5.63636364  5.72727273  5.81818182
#   5.90909091  6.          6.09090909  6.18181818  6.27272727  6.36363636
#   6.45454545  6.54545455  6.63636364  6.72727273  6.81818182  6.90909091
#   7.          7.09090909  7.18181818  7.27272727  7.36363636  7.45454545
#   7.54545455  7.63636364  7.72727273  7.81818182  7.90909091  8.
# ...

# %% [markdown]
# NumPy Array Functions
#
# np.array:
#
# This function creates a new NumPy array from a given input (like lists, tuples, etc.).
# It copies the data into a new array, meaning modifications to the original data won't affect the new array.
#
# np.asarray:
#
# This function converts the input to an array, but it does not create a new copy if the input is already an array (i.e., if the input is a NumPy array, it will return it as-is).
# It’s generally more efficient than np.array because it avoids unnecessary copying.
#
# np.asanyarray:
#
# Similar to np.asarray, but it allows for subclasses of arrays (like masked arrays) to remain as their respective types.
# If the input is a subclass of ndarray, it will return that subclass instead of a base ndarra.
#
# Copying in Python
# Shallow Copy:
#
# A shallow copy creates a new object but does not create copies of the nested objects. Instead, it copies references to those nested objects.
#
# Changes to mutable nested objects in the original will reflect in the shallow copy (and vice versa).
#
# Deep Copy:
#
# A deep copy creates a new object and recursively copies all nested objects, creating entirely independent copies.
#
# Changes to the original object or its nested objects do not affect the deep copy.

# %%
import numpy as np

# Generate a 3x3 array with random floats between 5 and 20
random_array = np.random.uniform(5, 20, (3, 3))

# Round each number to 2 decimal places
rounded_array = np.round(random_array, 2)

print(rounded_array)
# Out:
# [[18.74  8.12  8.87]
#  [11.46 16.72  5.57]
#  [17.12 18.64  7.01]]

# %%
import numpy as np

# Create a 5x6 array with random integers between 1 and 10
random_array = np.random.randint(1, 11, size=(5, 6))

# Display the original array
print("Original Array:")
print(random_array)

# a) Extract all even integers from the array
even_integers = random_array[random_array % 2 == 0]
print("\nEven Integers:")
print(even_integers)

# b) Extract all odd integers from the array
odd_integers = random_array[random_array % 2 != 0]
print("\nOdd Integers:")
print(odd_integers)
# Out:
# Original Array:
# [[10  2  9  7  6  3]
#  [ 7  5  8  3  7  6]
#  [10  9  9  5  4  4]
#  [ 3  1  6  1  5  9]
#  [ 9  1  6  1  7  8]]
#
# Even Integers:
# [10  2  6  8  6 10  4  4  6  6  8]
#
# Odd Integers:
# [9 7 3 7 5 3 7 9 9 5 3 1 1 5 9 9 1 1 7]

# %%
import numpy as np

# Create a 3D array with random integers between 1 and 10
array_3d = np.random.randint(1, 11, size=(3, 3, 3))

# Display the original 3D array
print("Original 3D Array:")
print(array_3d)

# a) Find the indices of the maximum values along each depth level (third axis)
max_indices = np.argmax(array_3d, axis=2)
print("\nIndices of Maximum Values along Each Depth Level:")
print(max_indices)

# b) Perform element-wise multiplication of the array with itself
elementwise_multiplication = array_3d * array_3d
print("\nElement-wise Multiplication of the Array:")
print(elementwise_multiplication)
# Out:
# Original 3D Array:
# [[[ 7  5  9]
#   [ 9  2 10]
#   [ 7  8  9]]
#
#  [[ 9  6  5]
#   [ 6 10  9]
#   [ 7  6  2]]
#
#  [[ 7  2  5]
#   [ 3  4 10]
#   [ 9  4  8]]]
#
# Indices of Maximum Values along Each Depth Level:
# [[2 2 2]
#  [0 1 0]
#  [0 2 0]]
#
# Element-wise Multiplication of the Array:
# [[[ 49  25  81]
#   [ 81   4 100]
#   [ 49  64  81]]
#
#  [[ 81  36  25]
#   [ 36 100  81]
#   [ 49  36   4]]
#
#  [[ 49   4  25]
#   [  9  16 100]
#   [ 81  16  64]]]

# %%
import pandas as pd

# Sample dataset
data = {
    'Name': ['Varun', 'Sachin', 'Shiv'],
    'Phone': ['9753064366', '6263456780', '8085278181']
}

# Create a DataFrame
df = pd.DataFrame(data)

# Display the original DataFrame
print("Original DataFrame:")
print(df)

# Clean the 'Phone' column
df['Phone'] = df['Phone'].str.replace(r'\D', '', regex=True).astype(float)

# Display the cleaned DataFrame
print("\nCleaned DataFrame:")
print(df)

# Display the attributes and data types of each column
print("\nDataFrame Attributes and Data Types:")
print(df.dtypes)
# Out:
# Original DataFrame:
#      Name       Phone
# 0   Varun  9753064366
# 1  Sachin  6263456780
# 2    Shiv  8085278181
#
# Cleaned DataFrame:
#      Name         Phone
# 0   Varun  9.753064e+09
# 1  Sachin  6.263457e+09
# 2    Shiv  8.085278e+09
#
# DataFrame Attributes and Data Types:
# Name      object
# Phone    float64
# dtype: object

# %%
import pandas as pd
import numpy as np

# Generate 35 random integers between 1 and 6
random_integers = np.random.randint(1, 7, size=35)

# Create a DataFrame from the series
df = pd.DataFrame(random_integers.reshape(7, 5), columns=[f'Col_{i+1}' for i in range(5)])

# Display the DataFrame
print("7x5 DataFrame:")
print(df)
# Out:
# 7x5 DataFrame:
#    Col_1  Col_2  Col_3  Col_4  Col_5
# 0      4      5      2      2      6
# 1      5      1      1      5      6
# 2      1      5      5      2      6
# 3      6      3      2      1      1
# 4      5      2      2      3      4
# 5      3      6      5      2      3
# 6      2      1      3      2      2

# %%
import pandas as pd
import numpy as np

# a) Create the first Series with random numbers ranging from 10 to 50
series1 = pd.Series(np.random.randint(10, 51, size=50))

# b) Create the second Series with random numbers ranging from 100 to 1000
series2 = pd.Series(np.random.randint(100, 1001, size=50))

# c) Create a DataFrame by joining these Series by column
df = pd.DataFrame({'col1': series1, 'col2': series2})

# Display the DataFrame
print("DataFrame:")
print(df)
# Out:
# DataFrame:
#     col1  col2
# 0     39   867
# 1     42   520
# 2     19   773
# 3     18   616
# 4     28   269
# 5     29   485
# 6     37   731
# 7     43   270
# 8     18   953
# 9     10   648
# 10    10   553
# 11    29   598
# 12    36   835
# 13    39   386
# 14    33   236
# 15    35   798
# 16    20   924
# 17    31   845
# 18    46   565
# 19    29   994
# 20    13   317
# 21    36   594
# 22    23   624
# 23    45   607
# 24    43   797
# 25    35   922
# 26    39   701
# 27    25   386
# 28    40   370
# 29    14   474
# 30    28   571
# 31    36   432
# 32    48   510
# 33    14   684
# 34    16   573
# 35    15   331
# 36    47   925
# 37    18   477
# 38    21   400
# 39    18   112
# 40    39   856
# 41    36   738
# 42    24   710
# 43    24   363
# 44    47   976
# 45    10   247
# 46    14   228
# 47    44   511
# 48    23   209
# 49    21   920

# %%
import pandas as pd

# Read the dataset
file_path = 'data.csv'  # Adjust this path as needed


# a) Delete the 'Email', 'Phone', and 'Date of Birth' columns from the dataset


# b) Delete the rows containing any missing values
df.dropna(inplace=True)

# d) Print the final output
print("Final DataFrame after deletions:")
print(df)
# Out:
# Final DataFrame after deletions:
#     col1  col2
# 0     39   867
# 1     42   520
# 2     19   773
# 3     18   616
# 4     28   269
# 5     29   485
# 6     37   731
# 7     43   270
# 8     18   953
# 9     10   648
# 10    10   553
# 11    29   598
# 12    36   835
# 13    39   386
# 14    33   236
# 15    35   798
# 16    20   924
# 17    31   845
# 18    46   565
# 19    29   994
# 20    13   317
# 21    36   594
# 22    23   624
# 23    45   607
# 24    43   797
# 25    35   922
# 26    39   701
# 27    25   386
# 28    40   370
# 29    14   474
# 30    28   571
# 31    36   432
# 32    48   510
# 33    14   684
# 34    16   573
# 35    15   331
# 36    47   925
# 37    18   477
# 38    21   400
# 39    18   112
# 40    39   856
# 41    36   738
# 42    24   710
# 43    24   363
# 44    47   976
# 45    10   247
# 46    14   228
# 47    44   511
# 48    23   209
# 49    21   920

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1
x = np.random.rand(100)
y = np.random.rand(100)

# a) Create a scatter plot
plt.scatter(x, y, color='red', marker='o', label='Data Points')

# b) Add a horizontal line at y = 0.5
plt.axhline(y=0.5, color='blue', linestyle='--', label='y = 0.5')

# c) Add a vertical line at x = 0.5
plt.axvline(x=0.5, color='green', linestyle=':', label='x = 0.5')

# d) Label the axes
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# e) Set the title of the plot
plt.title('Advanced Scatter Plot of Random Values')

# f) Display a legend
plt.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create a date range
dates = pd.date_range(start='2023-01-01', periods=100)

# Create random data for Temperature and Humidity
temperature = np.random.uniform(low=15, high=35, size=len(dates))  # Temperature between 15 and 35 degrees
humidity = np.random.uniform(low=30, high=90, size=len(dates))    # Humidity between 30% and 90%

# Create a DataFrame
data = pd.DataFrame({'Date': dates, 'Temperature': temperature, 'Humidity': humidity})

# Set the Date as the index
data.set_index('Date', inplace=True)

# a) Plot the 'Temperature' and 'Humidity' on the same plot with different y-axes
fig, ax1 = plt.subplots()

# Plot Temperature on the left y-axis
ax1.plot(data.index, data['Temperature'], color='tab:red', label='Temperature')
ax1.set_xlabel('Date')
ax1.set_ylabel('Temperature (°C)', color='tab:red')
ax1.tick_params(axis='y', labelcolor='tab:red')

# Create a second y-axis for Humidity
ax2 = ax1.twinx()
ax2.plot(data.index, data['Humidity'], color='tab:blue', label='Humidity')
ax2.set_ylabel('Humidity (%)', color='tab:blue')
ax2.tick_params(axis='y', labelcolor='tab:blue')

# b) Label the x-axis
ax1.set_xlabel('Date')

# c) Set the title of the plot
plt.title('Temperature and Humidity Over Time')

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generate 1000 samples from a normal distribution
data = np.random.normal(loc=0, scale=1, size=1000)  # mean=0, std=1

# a) Plot a histogram of the data with 30 bins
plt.hist(data, bins=30, density=True, alpha=0.6, color='g', label='Histogram')

# b) Overlay a line plot representing the normal distribution's PDF
xmin, xmax = plt.xlim()  # Get the limits of the x-axis
x = np.linspace(xmin, xmax, 100)  # Generate values for x-axis
p = norm.pdf(x, loc=0, scale=1)  # Calculate the PDF for the normal distribution
plt.plot(x, p, 'k', linewidth=2, label='PDF')

# c) Label the axes
plt.xlabel('Value')
plt.ylabel('Frequency/Probability')

# d) Set the title of the plot
plt.title('Histogram with PDF Overlay')

# Show legend
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generate 1000 samples from a normal distribution
data = np.random.normal(loc=0, scale=1, size=1000)  # mean=0, std=1

# a) Plot a histogram of the data with 30 bins
plt.hist(data, bins=30, density=True, alpha=0.6, color='g', label='Histogram')

# b) Overlay a line plot representing the normal distribution's PDF
xmin, xmax = plt.xlim()  # Get the limits of the x-axis
x = np.linspace(xmin, xmax, 100)  # Generate values for x-axis
p = norm.pdf(x, loc=0, scale=1)  # Calculate the PDF for the normal distribution
plt.plot(x, p, 'k', linewidth=2, label='PDF')

# c) Label the axes
plt.xlabel('Value')
plt.ylabel('Frequency/Probability')

# d) Set the title of the plot
plt.title('Histogram with PDF Overlay')

# Show legend
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generate two random arrays
np.random.seed(0)  # For reproducibility
x = np.random.uniform(-10, 10, 100)
y = np.random.uniform(-10, 10, 100)

# Create a DataFrame to hold the data and add a 'Quadrant' column
data = pd.DataFrame({'X': x, 'Y': y})

# Define the quadrant based on the position of (X, Y)
def determine_quadrant(row):
    if row['X'] > 0 and row['Y'] > 0:
        return 'Quadrant 1'
    elif row['X'] < 0 and row['Y'] > 0:
        return 'Quadrant 2'
    elif row['X'] < 0 and row['Y'] < 0:
        return 'Quadrant 3'
    elif row['X'] > 0 and row['Y'] < 0:
        return 'Quadrant 4'
    else:
        return 'Origin'

data['Quadrant'] = data.apply(determine_quadrant, axis=1)

# Create a Seaborn scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='X', y='Y', hue='Quadrant', palette='Set1', style='Quadrant', markers=['o', 's', 'D', '^'], s=100)

# Add legend, labels, and title
plt.legend(title='Quadrants')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Quadrant-wise Scatter Plot')

# Display the plot
plt.show()

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
import numpy as np

# Prepare the output for Jupyter Notebook (remove if running in a script)
output_notebook()

# Generate x values
x = np.linspace(0, 2 * np.pi, 100)  # 100 points from 0 to 2π
y = np.sin(x)  # Calculate sine of x

# Create a new plot
p = figure(title='Sine Wave Function', x_axis_label='X-axis (radians)', y_axis_label='Y-axis (amplitude)',
           width=800, height=400)

# Add grid lines
p.grid.grid_line_alpha = 0.3  # Set the transparency of grid lines

# Plot the sine wave
p.line(x, y, line_width=2, color='blue', legend_label='Sine Wave')

# Customize legend
p.legend.location = "top_left"
p.legend.click_policy = "hide"

# Show the plot
show(p)
# Out:
#   <div id="de808ee8-a3de-4359-84ef-abcf919e3b8d" data-root-id="p1001" style="display: contents;"></div>

# %%
import plotly.graph_objects as go
import numpy as np

# Generate random data
np.random.seed(0)  # For reproducibility
x = np.linspace(0, 10, 100)  # 100 points from 0 to 10
y = np.random.rand(100)  # Random values

# Create a line plot
fig = go.Figure()

# Add a trace for the line plot
fig.add_trace(go.Scatter(x=x, y=y, mode='lines', name='Random Data'))

# Update layout with title and axis labels
fig.update_layout(
    title='Simple Line Plot',
    xaxis_title='X-axis',
    yaxis_title='Y-axis',
    template='plotly_white'
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
import numpy as np

# Generate random data
np.random.seed(0)  # For reproducibility
labels = [f'Category {i+1}' for i in range(5)]  # 5 categories
values = np.random.randint(10, 100, size=len(labels))  # Random values

# Create a pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, textinfo='label+percent')])

# Update layout with title
fig.update_layout(title='Interactive Pie Chart')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
